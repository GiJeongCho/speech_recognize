# %%
import re
from kiwipiepy import Kiwi

# %%
kiwi = Kiwi(num_workers=0, model_path=None, load_default_dict=True, integrate_allomorph=True, model_type='cong', typos=None, typo_cost_threshold=2.5)
# Out:
# /tmp/ipykernel_3676685/144359186.py:1: DeprecationWarning: behavior of `num_workers=0` is changed since v0.21.0. If you want to keep the previous behavior, please set `num_workers=-1`.
#   kiwi = Kiwi(num_workers=0, model_path=None, load_default_dict=True, integrate_allomorph=True, model_type='cong', typos=None, typo_cost_threshold=2.5)

# %%
kiwi.analyze("""
그래서 오늘 공밀중으로 다 작업을 할 예정이고 마무리되는 대로 공유하는 걸로 하겠습니다. 저는 뭐 저번 주에 모델 여러 개 퓨어씨 해봤고 이번 주는 지금 녹음하고 있는 거 한번 해보려고요 빨리 해서 끝내볼게요 개발 목록?
""")
# Out:
# [([Token(form='그래서', tag='MAJ', start=1, len=3),
#    Token(form='오늘', tag='MAG', start=5, len=2),
#    Token(form='공', tag='NNG', start=8, len=1),
#    Token(form='밀', tag='NNG', start=9, len=1),
#    Token(form='중', tag='NNB', start=10, len=1),
#    Token(form='으로', tag='JKB', start=11, len=2),
#    Token(form='다', tag='MAG', start=14, len=1),
#    Token(form='작업', tag='NNG', start=16, len=2),
#    Token(form='을', tag='JKO', start=18, len=1),
#    Token(form='하', tag='VV', start=20, len=1),
#    Token(form='ᆯ', tag='ETM', start=20, len=1),
#    Token(form='예정', tag='NNG', start=22, len=2),
#    Token(form='이', tag='VCP', start=24, len=1),
#    Token(form='고', tag='EC', start=25, len=1),
#    Token(form='마무리', tag='NNG', start=27, len=3),
#    Token(form='되', tag='XSV', start=30, len=1),
#    Token(form='는', tag='ETM', start=31, len=1),
#    Token(form='대로', tag='NNB', start=33, len=2),
#    Token(form='공유', tag='NNG', start=36, len=2),
# ...
