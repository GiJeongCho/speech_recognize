# %%
import re
from kiwipiepy import Kiwi

# %%
kiwi = Kiwi(num_workers=0, model_path=None, load_default_dict=True, integrate_allomorph=True, model_type='cong', typos=None, typo_cost_threshold=2.5)
# Out:
# /tmp/ipykernel_3676685/144359186.py:1: DeprecationWarning: behavior of `num_workers=0` is changed since v0.21.0. If you want to keep the previous behavior, please set `num_workers=-1`.
#   kiwi = Kiwi(num_workers=0, model_path=None, load_default_dict=True, integrate_allomorph=True, model_type='cong', typos=None, typo_cost_threshold=2.5)

# %%
kiwi.analyze("""
 "당장 다음주라도 있는게 베스트인거죠 최대한 빠르게 오는게 더 좋겠죠 그리고 데이터 인아웃 데이터는 일단은 정리가 되어있는 자료를 찾았는데 거기에서 필수적으로 돼야 되는 것과 아닌 것들이 있어서 그걸 좀 분류를 하고 나면은 입출력 데이터는 어느 정도 정리가 될 것 같습니다."
""")
# Out:
# [([Token(form='"', tag='SSO', start=2, len=1),
#    Token(form='당장', tag='NNG', start=3, len=2),
#    Token(form='다음', tag='NNG', start=6, len=2),
#    Token(form='주', tag='NNG', start=8, len=1),
#    Token(form='이', tag='VCP', start=9, len=0),
#    Token(form='라도', tag='EC', start=9, len=2),
#    Token(form='있', tag='VA', start=12, len=1),
#    Token(form='는', tag='ETM', start=13, len=1),
#    Token(form='것', tag='NNB', start=14, len=1),
#    Token(form='이', tag='JKS', start=14, len=1),
#    Token(form='베스트', tag='NNG', start=16, len=3),
#    Token(form='이', tag='VCP', start=19, len=1),
#    Token(form='ᆫ', tag='ETM', start=19, len=1),
#    Token(form='거', tag='NNB', start=20, len=1),
#    Token(form='이', tag='VCP', start=21, len=0),
#    Token(form='죠', tag='EF', start=21, len=1),
#    Token(form='최대한', tag='MAG', start=23, len=3),
#    Token(form='빠르', tag='VA', start=27, len=2),
#    Token(form='게', tag='EC', start=29, len=1),
#    Token(form='오', tag='VV', start=31, len=1),
# ...
